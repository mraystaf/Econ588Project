# %%
import numpy as np
from scipy.stats import nbinom, norm, binom, uniform
from matplotlib import pyplot as plt
import pandas as pd
from NBinomRandomDataGenerator import NBinomRandomDataGenerator
# import import_ipynb
# from NegativeBinomial_Likelihood import NegativeBinomialAnalysis

# %%
test1 = NBinomRandomDataGenerator(size=10000, x_distribution='uniform') #x_loc=5, x_scale=10, beta=np.array([0,-0.5])
data = test1.createVaryingCensoredData(generate_plots=True)
data['Desired Starting Salary ($)'] = data['Desired Starting Salary ($)'].round()
data
# Out:
#       Desired Starting Salary ($)  Rejected Job Applications  Censored
# 0                        128489.0                         48         0
# 1                         31899.0                          8         0
# 2                        119795.0                         42         0
# 3                         82404.0                          7         1
# 4                         81050.0                         10         0
# ...                           ...                        ...       ...
# 9995                      61411.0                          8         0
# 9996                      38780.0                          7         0
# 9997                      44277.0                          3         1
# 9998                      68922.0                          2         0
# 9999                     123351.0                         17         0
#
# [10000 rows x 3 columns]
