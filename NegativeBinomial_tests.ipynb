# %%
import numpy as np
from scipy.stats import nbinom, norm, binom, uniform
from matplotlib import pyplot as plt
import pandas as pd
from NBinomRandomDataGenerator import NBinomRandomDataGenerator

# %%
test1 = NBinomRandomDataGenerator(size=100, x_distribution='uniform')
data = test1.createVaryingCensoredData(generate_plots=True)
data
# Out:
#     Desired Starting Salary ($)  Rejected Job Applications  Censored
# 0                         38454                          0         1
# 1                         87779                         33         0
# 2                         89766                          3         0
# 3                        124423                        232         0
# 4                        125761                         52         0
# ..                          ...                        ...       ...
# 95                        84214                          6         1
# 96                        71715                         32         0
# 97                        69791                          1         1
# 98                        71242                          4         0
# 99                        78413                         27         0
#
# [100 rows x 3 columns]

# %%
test2 = NBinomRandomDataGenerator(size=100, x_distribution='normal', x_loc=60000, x_scale=7000, beta=np.array([0, -1e-4]))
data = test2.createVaryingCensoredData(generate_plots=True)
data
# Out:
#     Desired Starting Salary ($)  Rejected Job Applications  Censored
# 0                         52369                         25         1
# 1                         55373                        256         0
# 2                         64229                        335         0
# 3                         60371                        316         0
# 4                         66774                        294         0
# ..                          ...                        ...       ...
# 95                        63215                        282         0
# 96                        58660                         17         1
# 97                        59545                          3         1
# 98                        70664                        393         0
# 99                        67250                        510         0
#
# [100 rows x 3 columns]

# %%
test3 = NBinomRandomDataGenerator(size=100, x_distribution='uniform', x_loc=90000, x_scale=20000, beta=np.array([0, -7e-5]))
data = test3.createUniversallyCensoredData(1000, generate_plots=True)
data
# Out:
#     Desired Starting Salary ($)  Rejected Job Applications  Censored
# 0                        109366                         32         0
# 1                         98147                        111         0
# 2                        104462                        992         0
# 3                        104431                       1000         1
# 4                         99087                        166         0
# ..                          ...                        ...       ...
# 95                        97613                        137         0
# 96                        94020                       1000         1
# 97                        98290                       1000         1
# 98                       109782                       1000         1
# 99                        95241                        681         0
#
# [100 rows x 3 columns]
